# %% [markdown]
# # Exploratory Analysis
#
# Run the ETL pipeline first, then use this notebook to explore the cleaned Open Food Facts product data.

# %%
import pandas as pd
from pathlib import Path

data_path = Path('../data/processed/openfoodfacts_clean_products.csv')

if not data_path.exists():
    raise FileNotFoundError('Run python run_pipeline.py --page-size 100 --search-terms chocolate first.')

df = pd.read_csv(data_path)
df.head()

# %%
df.info()
df.describe(include='all')

# %%
df['main_category'].value_counts().head(10)

# %%
df['nutriscore_grade'].value_counts(dropna=False)
